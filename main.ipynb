# %%
import pandas as pd

tabela = '../Finances_for_two/planilha_organizador_financeiro.xlsx'

valor_procurado = input("Digite o nome que procura: ").casefold()

for item in usuarios[0]['receita']:
    if item.get('nome') == valor_procurado:
        usuarios[0]['receita'].remove(item)

# %%
tabela = '../Finances_for_two/planilha_organizador_financeiro.xlsx'

tabela = pd.read_excel(tabela)
tabela = tabela[tabela['nome'].str.casefold() == 'manicure']
# Out:
# Index([5], dtype='int64')

# %%
tabela = '../Finances_for_two/planilha_organizador_financeiro.xlsx'

info = tabela.loc['manicure','nome']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[226], line 3
#       1 tabela = '../Finances_for_two/planilha_organizador_financeiro.xlsx'
# ----> 3 info = tabela.loc['manicure','nome']
#
# AttributeError: 'str' object has no attribute 'loc'
